# %% [markdown]
# <a href="https://colab.research.google.com/github/Miglio39/Inmersion/blob/main/aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bienvenidos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 

inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion de datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'banos', 'area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'banos','Área':'area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(2)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 4667  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 5017         Casa              Casa en venta en La Candelaria             6
#
#       banos  area              Barrio                                 UPZ  \
# 4667      1    40  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 5017      6   540       La Candelaria                       La Candelaria
#
#                 Valor
# 4667    $ 200.000.000
# 5017  $ 2.900.000.000

# %%
inmuebles.info
# Out:
# <bound method DataFrame.info of              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  banos  area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   banos         9520 non-null   int64
#  4   area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# banos                                         1
# area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
type (inmuebles['Habitaciones'][300:305])
# Out:
# pandas.core.series.Series

# %%
# Out:
# 0       3
# 1       4
# 2       3
# 3       3
# 4       2
#        ..
# 9515    3
# 9516    2
# 9517    8
# 9518    3
# 9519    3
# Name: Habitaciones, Length: 9520, dtype: int64

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'banos', 'area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                    Descripcion  \
# 2492  Apartamento         Apartamento en venta en Barrios Unidos
# 6512  Apartamento                Apartamento en venta en Mazuren
# 6105  Apartamento     Apartamento en venta en Zona Noroccidental
# 1757  Apartamento  Apartamento en venta en Ciudadela Colsubsidio
# 7105  Apartamento     Apartamento en venta en Zona Noroccidental
#
#       Habitaciones  banos  area                 Barrio  \
# 2492             1      2    81         Barrios Unidos
# 6512             3      2   120                Mazuren
# 6105             3      2    74     Zona Noroccidental
# 1757             3      1    59  Ciudadela Colsubsidio
# 7105             3      2    71     Zona Noroccidental
#
#                                      UPZ          Valor
# 2492                           Los Andes  $ 575.000.000
# 6512                            El Prado  $ 390.000.000
# 6105  CHAPINERO: Pardo Rubio + Chapinero  $ 255.000.000
# ...

# %%
(inmuebles.Barrio=='Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio=='Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio=='Chico Reservado')

# %%
type (inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles [inmuebles_chico]

# %%
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       banos  area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.area.mean()
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()

# %%
inmuebles_barrio
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles_barrio.head().plot.bar()
# Out:
# <Axes: >

# %%
inmuebles.Barrio
# Out:
# 0           Zona Noroccidental
# 1                     Castilla
# 2              Chico Reservado
# 3                      Usaquén
# 4                  Bella Suiza
#                  ...
# 9515                   Kennedy
# 9516    Parque Central Bavaria
# 9517                  Restrepo
# 9518                  Engativa
# 9519                   Tintala
# Name: Barrio, Length: 9520, dtype: object

# %%
# 1.realizar el promedio de area de todos los barrios mas un grafico de top10
# 2. consultar otros datos estadisticos, como el conteo la mediana, valores maximos y  minimos por ejem cual es la csa mas barata.

# %%
barrios_area = inmuebles.groupby('Barrio')['area'].mean()
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
promedio_area_barrios = inmuebles.groupby("Barrio")["area"].mean()
promedio_area_barrios
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: area, Length: 149, dtype: float64

# %%
promedio_area_barrios.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.describe()
# Out:
#        Habitaciones        banos           area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
## AULA 2

# %%
inmuebles.sample(5)
# Out:
#              Tipo                      Descripcion  Habitaciones  banos  area  \
# 6974         Casa         Casa en venta en Kennedy             7      3   392
# 4144  Apartamento     Apartamento en venta en Usme             1      1    51
# 7002  Apartamento  Apartamento en venta en Usaquén             1      1    35
# 7862  Apartamento  Apartamento en venta en Usaquén             3      3    69
# 3111  Apartamento  Apartamento en venta en Usaquén             3      4   211
#
#        Barrio                                UPZ            Valor
# 6974  Kennedy                    Kennedy Central    $ 800.000.000
# 4144     Usme  USME: Alfonso López + Ciudad Usme    $ 371.000.000
# 7002  Usaquén                            Usaquén    $ 205.000.000
# 7862  Usaquén                            Usaquén    $ 290.000.000
# 3111  Usaquén                            Usaquén  $ 1.400.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   banos         9520 non-null   int64
#  4   area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[3111]
# Out:
# '$ 1.400.000.000'

# %%
type (inmuebles.Valor[3111])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type (inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] =valor[0]
inmuebles['Precio'] =valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                          Descripcion  Habitaciones  banos  \
# 7701         Casa             Casa en venta en Kennedy             6      4
# 6411         Casa  Casa en venta en Zona Noroccidental             3      3
# 3004  Apartamento      Apartamento en venta en Usaquén             3      2
#
#       area              Barrio                                 UPZ  \
# 7701   275             Kennedy                     Kennedy Central
# 6411   296  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3004    75             Usaquén                             Usaquén
#
#                 Valor Moneda         Precio
# 7701    $ 750.000.000      $    750.000.000
# 6411  $ 1.290.000.000      $  1.290.000.000
# 3004    $ 400.000.000      $    400.000.000

# %%
inmuebles.info()
#sigue siendo tipo objeto
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   banos         9520 non-null   int64
#  4   area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles ['Precio'] = inmuebles ['Precio'].str.replace('.','', regex=True)

# %%
inmuebles.sample(2)
# Out:
#              Tipo                       Descripcion  Habitaciones  banos  \
# 7919  Apartamento      Apartamento en venta en Suba             4      6
# 1635  Apartamento  Apartamento en venta en Fontibón             3      2
#
#       area    Barrio       UPZ            Valor Moneda      Precio
# 7919   350      Suba      Suba  $ 1.300.000.000      $  1300000000
# 1635    48  Fontibón  Fontibón    $ 214.830.000      $   214830000

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000

# %%
inmuebles.sample(2)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 2302  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 278   Apartamento             Apartamento en venta en Usaquén             2
#
#       banos  area              Barrio                                 UPZ  \
# 2302      3    78  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 278       3   109             Usaquén                             Usaquén
#
#               Valor Moneda     Precio  Precio_Millon
# 2302  $ 550.000.000      $  550000000          550.0
# 278   $ 570.000.000      $  570000000          570.0

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   banos          9520 non-null   int64
#  4   area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        banos           area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
inmuebles.describe()
# Out:
#        Habitaciones   banos      area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00
